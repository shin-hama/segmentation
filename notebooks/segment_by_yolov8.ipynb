# %% [markdown]
# # Segmentation by yolo v8

# %%
import cv2
import numpy as np

# %%
from ultralytics import YOLO

# モデルをロード
model = YOLO('../models/yolov8n-seg.pt')  # 公式モデルをロード

# %% [markdown]
# ## 推論

# %%
# image_path = 'https://ultralytics.com/images/bus.jpg'
image_path = "./test.jpg"

# save = True にすることで結果を画像で保存する
results = model(image_path, save=True, save_txt=True)
# Out:
# image 1/1 c:\Users\hamada\workspace\labo\segmentation\notebooks\test.jpg: 480x640 1 cat, 1 suitcase, 1 couch, 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to c:\Users\hamada\workspace\labo\segmentation\runs\segment\predict6
# 1 label saved to c:\Users\hamada\workspace\labo\segmentation\runs\segment\predict6\labels

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[189, 202, 234],
#          [142, 154, 182],
#          [186, 200, 219],
#          ...,
#          [165, 186, 207],
#          [166, 187, 209],
#          [168, 189, 211]],
#
#         [[209, 220, 252],
#          [141, 153, 181],
#          [188, 199, 219],
#          ...,
#          [167, 188, 209],
#          [168, 189, 211],
#          [170, 191, 213]],
#
#         [[154, 164, 194],
#          [149, 160, 187],
#          [183, 193, 211],
#          ...,
#          [169, 190, 211],
#          [170, 191, 213],
#          [171, 192, 214]],
#
#         ...,
#
#         [[ 97, 101, 106],
#          [ 98, 102, 107],
#          [ 99, 103, 108],
#          ...,
#          [185, 159, 129],
#          [182, 157, 125],
#          [183, 158, 126]],
#
#         [[ 91,  95, 100],
#          [ 92,  96, 101],
#          [ 92,  96, 101],
#          ...,
#          [184, 159, 127],
#          [187, 162, 130],
#          [189, 164, 132]],
#
#         [[ 92,  96, 101],
#          [ 90,  94,  99],
#          [ 89,  93,  98],
#          ...,
#          [186, 161, 129],
#          [189, 164, 132],
#          [185, 160, 128]]], dtype=uint8)
#  orig_shape: (3024, 4032)
#  path: 'c:\\Users\\hamada\\workspace\\labo\\segmentation\\notebooks\\test.jpg'
#  probs: None
#  save_dir: 'c:\\Users\\hamada\\workspace\\labo\\segmentation\\runs\\segment\\predict6'
#  speed: {'preprocess': 3.002166748046875, 'inference': 67.99936294555664, 'postprocess': 2.999544143676758}]

# %% [markdown]
# ## 出力結果の表示

# %%
import matplotlib.pyplot as plt
from pathlib import Path

# get filename
filename = Path(results[0].path).name

result_image = cv2.imread(f"{results[0].save_dir}/{filename}")
result_image = cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,10))
plt.imshow(result_image)
plt.axis('off')
plt.show()
